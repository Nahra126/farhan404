# %% [markdown]
# # TimeSeries Analysis and Forecasting¶
#    . DataTime Module of Python as Pandas datetimestamp

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# %%
now = datetime.now(ZoneInfo("Asia/Karachi"))
now
# Out:
# datetime.datetime(2026, 7, 9, 11, 7, 43, 85767, tzinfo=zoneinfo.ZoneInfo(key='Asia/Karachi'))

# %%
now.year
# Out:
# 2026

# %%
now.month
# Out:
# 7

# %%
now.day
# Out:
# 9

# %%
now.hour
# Out:
# 11

# %%
now.weekday()
# Out:
# 3

# %%
now.date()
# Out:
# datetime.date(2026, 7, 9)

# %%
now.time()
# Out:
# datetime.time(11, 7, 43, 85767)

# %%
datetime.strptime("2026-7-9 11:7:43","%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2026, 7, 9, 11, 7, 43)

# %%
type(now)
# Out:
# datetime.datetime
