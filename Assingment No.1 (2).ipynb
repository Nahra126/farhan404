# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
Name = "Farhan".upper()
print(Name)
# Out:
# FARHAN

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
Friut = input("Your Fav Fruit: ")

print(len(Friut))
# Out:
# Your Fav Fruit:  orange
# 6

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
Sentence = 'Python is fun'

New_Sentence = Sentence.replace('fun','awesome')

print(New_Sentence)
# Out:
# Python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
text = 'Hello World'

print(text.find('World'))
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
Email = input("entr your email: ").lower()

print(Email)
# Out:
# entr your email:  NAHRAF126@GMAIL.COM
# nahraf126@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
sentence = ' Python Programming '

text = sentence.strip()

print(text)
# Out:
# Python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
Sentence = 'Welcome to coding'

count = Sentence.count('o')

print(count)
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
user =int(input('your age: '))

print(user)
# Out:
# your age:  34
# 34

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
value = 15.99

result = int(value)

print(result)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
first_num = int(input('Enter first_num:'))
second_num = int(input('Enter second num:'))

add = first_num + second_num

print(add)
# Out:
# Enter first_num: 34
# Enter second num: 56
# 90

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
num = 100

convert =str(num)

print(type(convert))
# Out:
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
price = float(input('price:'))

result = int(price)

print(result)
# Out:
# price: 99.5
# 99

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
num1 =int('10')
num2 =int('20')

result = num1 + num2

print(result)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
num = float('50.5')

add = float(num+10)

print(add)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
user1 = input('your name:')
user2 = input( 'your city name: ')
name = user1
city = user2
print(f"Hello {name} Welcome to {city}")

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
num1 = int(input('your first number'))
num2 = int(input('your second number'))

result = (num1*num2)

print(result)
# Out:
# your first number 2
# your second number 3
# 6

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
user_colour = input('your fav color: ')

color = user_colour 

print(f'i also like {color}')
# Out:
# your fav color:  red
# i also like red

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
user_birth_year = int(input("your birth year: ")) 

current_year = 2026 

age = current_year -  user_birth_year

print(f'your age is {age}')
# Out:
# your birth year:  1999
# your age is 27

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
Name = input('your name is :')

multiply = Name * 5

print(multiply)
# Out:
# your name is : Farhan
# FarhanFarhanFarhanFarhanFarhan

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
user = input("your mobile number: ")

number = int(user)

print(f'apka mobile number ye ha {number}')
# Out:
# your mobile number:  923352974529
# apka mobile number ye ha 923352974529

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
a = 10
b = 3

result = 10 % 3

print(result)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
15 > 10 and 15 < 20
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
user = int(input('your number is :'))

if user > 100:
    print('your number is grater than 100')
else:
   print('sorry, your number is not grater than 100')
# Out:
# your number is : 34
# sorry, your number is not grater than 100

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
a = 50 
b = 100

if a == b:
    print('a is equal to b')
else:
    print('a is not equal to b')
# Out:
# a is not equal to b

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
15 > 10 or 15 > 20
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
user = int(input('your number is :'))

if user >= 0:
    print('your number is Positive')
else:
   print('sorry, your number is negative')
# Out:
# your number is : -65
# sorry, your number is negative

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
user_age = int(input('your number is :'))

if user_age >= 18:
    print('you are eligible for vote')
else:
   print('sorry, you are not eligible for vote')
# Out:
# your number is : 27
# you are eligible for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
number = int(input('your number'))

if number % 2 == 0:
    print('your number is even')
else:
    print('your number is odd')
# Out:
# your number 1
# your number is even

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
a = int(input('number'))
b = int(input('number'))

if a > b:
    print(f'{a}')
else:
    print(f'{b}')
# Out:
# number 45
# number 67
# 67

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
Marks = int(input('your number is :'))

if Marks > 33:
    print('pass')
else:
   print('Fail')
# Out:
# your number is : 23
# Fail

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
user = input('your name is: ')

if user != "":
    print('not empty')
else:
    print('empty')
# Out:
# your name is:  Farhan
# not empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
user = (input('your password is :'))

password = user

if password == 'python123' :
    print('Access Granted')
else:
   print('Wrong Password')
# Out:
# your password is : python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
number = float(input("enter your number "))
if number >= 90:
   grade = 'A'
elif number>= 80:
   grade = 'B'
elif number >= 70:
   grade = 'C'
else:
   grade = 'D'
print(grade)
# Out:
# enter your number  89
# B

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
Tempreture = float(input("enter Tempreture "))
if Tempreture > 30:
   Feel = 'HOT'
elif Tempreture>= 15:
   Feel = 'WARM'
else:
   Feel = 'COLD'
print(Feel)
# Out:
# enter Tempreture  14
# COLD

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
number = int(input("enter Your number"))
if number % 3==0:
    result = "yes divisible"
elif number % 5==0:
    result = "yes divisible"
elif number % 3==0 and number % 5==0:
    result = "yes divisible"
else:
    result = 'soory not divisible'
print(result)
# Out:
# enter Your number 5
# yes divisible

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
letter = (input("enter your letter"))

if letter in 'aeiou':
    show = 'Vowel'
else:
   show ='Constant'
print(show)
# Out:
# enter your letter v
# Constant

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
Shooping_amount = int(input("enter total amount "))

if Shooping_amount > 5000:
    discount = Shooping_amount*0.20
if Shooping_amount >= 2000:
    discount = Shooping_amount*0.10
else:
    discount = 0

print(f""" your total amount is {Shooping_amount}
           your discount is {discount}
           after-discount is {Shooping_amount-discount}""")
# Out:
# enter total amount  5000
#  your total amount is 5000
#            your discount is 500.0
#             your  after-discount is 4500.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
Age = int(input("enter your age "))

if Age <= 12:
    Category = 'Child'
if Age <= 19:
    Category = 'Teenager'
if Age <= 59:
    Category = 'Adult'
else:
    Category = 'Senior Citizen'
print(Category)
# Out:
# enter your age  59
# Adult

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
Year = int(input('enter year'))

if Year % 4 == 0:
    print('This is leap year')
else:
    print  ('This is not leap year')
# Out:
# enter year 2028
# This is leap year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
week = int(input("Enter week number (1-7): "))

if week == 1:
    output = 'Saturday'
elif week == 2:
    output = 'Sunday'
elif week == 3:
    output = 'Monday'
elif week == 4:
    output = 'Tuesday'
elif week == 5:
    output = 'Wednesday'
elif week == 6:
    output = 'Thursday'
elif week == 7:
    output = 'Friday'
else:
    output = 'invalid number'
print(output)
# Out:
# Enter week number (1-7):  9
# invalid number

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
num1 = int(input('enter your number'))
num2 = int(input('enter your number'))
operators = (input('enter your operator'))

if operators == '+':
    calculate = num1 + num2
elif operators == '*':
    calculate = num1 * num2
elif operators == '-':
    calculate = num1 - num2
elif operators == '/':
    calculate = num1 / num2
else:
    calculate = 'Worng oprators'
print(calculate)
# Out:
# enter your number 67
# enter your number 89
# enter your operator *
# 5963

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
weight = int(input('enter your weight'))
height = float(input('enter your height'))

BMI = weight / (height**2)

if BMI < 18.5:
    output = 'Under weight'
elif BMI < 24.9:
    output = 'Normal'
elif BMI < 29.9:
    output = 'overweight'
else:
    output = 'obese'
print(output)
# Out:
# enter your weight 70
# enter your height 3
# Under weight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
Balance = 500000
pin = int(input('enter your pin'))
if pin ==  2983:
    amount = int(input('enter your amt'))
    if amount <=  Balance:
        print('witdrawal success')
    else:
        print('low balace')
else:
    print('incorrect pin')
# Out:
# enter your pin 2983
# enter your amt 600000
# low balace

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
username = 'Farhan'
Pass = 2233

user = (input('enter your username'))
if user == username :
    Password = int(input('enter your pass'))
    if  Password == Pass :
        print('Login success')
    else:
        print('incorrect password')
else:
    print('incorrect username')
# Out:
# enter your username Farhan
# enter your pass 4444
# incorrect password

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b:
    if a > c:
        print("Largest number is:", a)
    else:
        print("Largest number is:", c)
else:
    if b > c:
        print("Largest number is:", b)
    else:
        print("Largest number is:", c)
# Out:
# Enter first number:  4
# Enter second number:  5
# Enter third number:  6
# Largest number is: 6

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
age = int(input("Enter your age: "))

if age >= 18:
    
    id_card = input("Do you have ID? (yes/no): ")

    if id_card == "yes":
        print("Ticket Issued")

    else:
        print("ID required")

else:
    print("You are under 18")
# Out:
# Enter your age:  67
# Do you have ID? (yes/no):  yes
# Ticket Issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
Marks = int(input("Enter your marks: "))

if Marks >= 80:
    
    interview = input("Do you clear interview (yes/no): ")

    if interview == "yes":
        print("Admission Done")

    else:
        print("interview clear nhi, doobara koshish karain")

else:
    print("mark kam hain, doobara koshish karain")
# Out:
# Enter your marks:  89
# Do you clear interview (yes/no):  yes
# Admission Done

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
numb = int(input('enter your number'))
if numb > 0:

    if numbe > 100:
        print('number 100 se bada ha')
    else:
        print('number 100 se chota ha')
else:
    print('number Negative ha')
# Out:
# enter your number 45
# number 100 se chota ha

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
order = input('veg ya non-veg')
if order == 'veg':
      item = input('paneer ya daal')
      if item == 'paneer':
          print('order comfirmed')
      else:
           print('order confirmed')
elif order == 'nonveg':
    item = input('mutton ya chicken')
    if item == 'mutton':
        print('order confirmed')
    else:
        print('order confirmed')
else:
     print('invalid option')
# Out:
# veg ya non-veg veg
# paneer ya daal daal
# order confirmed

# %% [markdown]
# ###

# %% [markdown]
# ## #52.Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
num = int(input("Enter a number: "))

if num >= 0 and num <= 9:
    print("Single digit number")

elif num >= 10 and num <= 99:
    print("Double digit number")

elif num >= 100 and num <= 999:
    print("Triple digit number")

else:
    print("Number is more than 3 digits")
# Out:
# Enter a number:  8888
# Number is more than 3 digits

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
salary = float(input("Enter your salary: "))
years = float(input("Enter your salary: "))


bonus = 0

if years > 5:
   bonus += (salary) * 0.05
else:
    print('not enogh services')

total_slary = bonus + salary

print(f"Total Salary: {total_slary}")
# Out:
# Enter your salary:  5000
# Enter your salary:  6
# Total Salary: 5250.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
side1 = int(input('enter side number'))
side2 = int(input('enter side number'))
side3 = int(input('enter side number'))

if side1 == side2 and side1 == side3:
    res = 'Equilateral Triangle'
elif side1 == side2 or side2 == side3 or side3 == side1:
    res = 'Isosceles Triangle'
else:
    res = 'Scalene Triangle'
print(res)
# Out:
# enter side number 4
# enter side number 5
# enter side number 6
# Scalene Triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
month = input("Enter month name: ")

if month in ["January", "March", "May", "July", "August", "October", "December"]:
    print("31 days")

elif month in ["April", "June", "September", "November"]:
    print("30 days")

elif month == "February":
    print("28 or 29 days")

else:
    print("Invalid month name")
# Out:
# Enter month name:  February
# 28 or 29 days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:   # pehle even check

    if num > 50:
        print("Even aur 50 se bada hai")

    else:
        print("Even aur 50 se chota hai")

else:
    print("Number Even nahi hai")
# Out:
# Enter a number:  46
# Even aur 50 se chota hai

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40 and science >= 40:
    print("Pass")

else:
    if maths < 40 and science < 40:
        print("Dono subjects weak hain")

    elif maths < 40:
        print("Maths weak hai")

    else:
        print("Science weak hai")
# Out:
# Enter Maths marks:  45
# Enter Science marks:  34
# Science weak hai

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
units = int(input("Enter units consumed: "))

if units <= 100:
    bill = 0

elif units <= 200:
    bill = (units - 100) * 5

else:
    bill = (100 * 5) + (units - 200) * 10

print("Your bill is:", bill)
# Out:
# Enter units consumed:  400
# Your bill is: 2500

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
score = int(input("Enter your score: "))

if score <= 50:
    print("Beginner Level")

else:
    print("Intermediate Level")

    boss = input("Did you clear boss level? (yes/no): ")

    if boss == "yes":
        print("Boss Level Achieved")
    else:
        print("Boss Level Not Achieved")

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "Farhan" and password == "1234":
    answer = input("Security Question: What is your pet name? ")
    if answer == "tommy":
        print("Access Granted")
    else:
        print("Wrong security answer")

else:
    print("Invalid username or password")
# Out:
# Enter username:  naveed
# Enter password:  1234
# Invalid username or password
